# %% [markdown]
# # Project VI — Validation Roadmap and Uncertainty Inventory
#
# This notebook reviews the uncertainty inventory and validation-priority outputs for the current Gaia-LAMOST candidate sample.

# %%
import pandas as pd

inventory = pd.read_csv('../data/processed/project_vi_uncertainty_inventory.csv')
priority = pd.read_csv('../data/processed/project_vi_validation_priority_candidates.csv')

print(inventory.shape)
inventory.head()

# %%
priority.head(10)

# %% [markdown]
# ## Notes
#
# - This is a validation-roadmap step, not full Monte Carlo propagation.
# - The next step should test Monte Carlo sampling on a small high-priority subset.
# - Distance, astrometric, radial-velocity, Galactic-potential, and chemical-abundance limitations should all be tracked in Project VI.
