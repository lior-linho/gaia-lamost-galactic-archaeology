# %% [markdown]
# # Project II — galpy Baseline Orbit Integration
#
# This notebook performs the first baseline orbit integration for the Project II candidate sample using `galpy` and `MWPotential2014`.

# %%
import pandas as pd

candidates = pd.read_csv('../data/processed/project_ii_galpy_orbit_candidates.csv')
summary = pd.read_csv('../data/processed/project_ii_galpy_orbit_summary.csv')

print(candidates.shape)
candidates.head()

# %%
summary

# %% [markdown]
# ## Notes
#
# - This is a baseline orbit-integration run.
# - The adopted potential is `MWPotential2014`.
# - No Monte Carlo uncertainty propagation is included yet.
# - Orbit-derived results should be compared with angular-momentum interpretation labels before population-level claims are made.
