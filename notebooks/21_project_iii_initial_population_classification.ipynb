# %% [markdown]
# # Project III — Initial Stellar Population Classification
#
# This notebook assigns first-pass stellar-population interpretation labels using Project II angular-momentum and galpy orbit diagnostics.

# %%
import pandas as pd

candidates = pd.read_csv('../data/processed/project_iii_population_candidates.csv')
summary = pd.read_csv('../data/processed/project_iii_population_summary.csv')

print(candidates.shape)
candidates.head()

# %%
summary

# %% [markdown]
# ## Notes
#
# - These are first-pass population interpretation labels.
# - They are not final structure-membership claims.
# - Literature-region comparison and uncertainty propagation are required before final classification.
