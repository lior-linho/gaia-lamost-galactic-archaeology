# %% [markdown]
# # Project II — Orbital-Family Interpretation
#
# This notebook summarizes the candidate-level orbital-family interpretation based on angular-momentum diagnostics.

# %%
import pandas as pd

candidates = pd.read_csv('../data/processed/project_ii_orbital_family_candidates.csv')
summary = pd.read_csv('../data/processed/project_ii_orbital_family_summary.csv')

print(candidates.shape)
candidates.head()

# %%
summary

# %% [markdown]
# ## Notes
#
# - The labels in this notebook are heuristic orbital-family interpretation tags.
# - They are not final population classifications.
# - Full orbit integration, uncertainty propagation, and literature comparison are required before final scientific claims.
