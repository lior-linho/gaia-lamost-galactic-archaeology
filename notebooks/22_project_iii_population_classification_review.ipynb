# %% [markdown]
# # Project III — Population Classification Review
#
# This notebook reviews Project III initial population labels and identifies priority candidates for later follow-up.

# %%
import pandas as pd

priority = pd.read_csv('../data/processed/project_iii_population_priority_candidates.csv')
summary = pd.read_csv('../data/processed/project_iii_population_review_summary.csv')

print(priority.shape)
priority.head(10)

# %%
summary

# %% [markdown]
# ## Notes
#
# - Priority tiers are heuristic research-triage labels.
# - They are designed to guide later literature comparison, chemical interpretation, and uncertainty propagation.
# - They are not final membership probabilities.
