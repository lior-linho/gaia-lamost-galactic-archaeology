# %% [markdown]
# # Project II — Orbit–Angular Momentum Consistency Analysis
#
# This notebook checks whether angular-momentum-based orbital-family interpretations are supported by baseline galpy orbit integration.

# %%
import pandas as pd

candidates = pd.read_csv('../data/processed/project_ii_orbit_angular_momentum_consistency.csv')
summary = pd.read_csv('../data/processed/project_ii_orbit_angular_momentum_consistency_summary.csv')

print(candidates.shape)
candidates.head()

# %%
summary

# %% [markdown]
# ## Notes
#
# - This is a consistency check between angular-momentum diagnostics and baseline orbit integration.
# - It does not yet include Monte Carlo uncertainty propagation.
# - Candidates with tension labels should be manually inspected in later work.
