# %% [markdown]
# # Project IV — Metallicity Structure and Chemical Readiness
#
# This notebook reviews the available chemical information for the Project III candidate sample. The current integrated table contains [Fe/H] but does not yet include alpha, Mg, Ca, or Si abundances.

# %%
import pandas as pd

candidates = pd.read_csv('../data/processed/project_iv_metallicity_candidates.csv')
summary = pd.read_csv('../data/processed/project_iv_metallicity_summary.csv')

print(candidates.shape)
candidates.head()

# %%
summary

# %% [markdown]
# ## Notes
#
# - This is a metallicity-readiness analysis, not a full chemical-tagging study.
# - The current integrated candidate table contains [Fe/H] only.
# - Later Project IV work should search for alpha, Mg, Ca, Si, or other abundance columns in the original LAMOST data products.
